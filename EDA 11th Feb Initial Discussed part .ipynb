# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Lead_Scoring.csv')
pd.set_option('display.max_columns',None)
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# ...

# %%
df.tail()
# Out:
#                                Prospect ID  Lead Number  \
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 9235  Landing Page Submission  Direct Traffic          Yes          No
# 9236  Landing Page Submission  Direct Traffic           No          No
# 9237  Landing Page Submission  Direct Traffic          Yes          No
# 9238  Landing Page Submission          Google           No          No
# 9239  Landing Page Submission  Direct Traffic           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# ...

# %%
len(df.columns)
# Out:
# 37

# %%
(df.isnull().sum()/len(df.index) )*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# ...

# %%
df.tail()
# Out:
#                                Prospect ID  Lead Number  \
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 9235  Landing Page Submission  Direct Traffic          Yes          No
# 9236  Landing Page Submission  Direct Traffic           No          No
# 9237  Landing Page Submission  Direct Traffic          Yes          No
# 9238  Landing Page Submission          Google           No          No
# 9239  Landing Page Submission  Direct Traffic           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# ...

# %%
df[df['Search']=='Yes'].head()
# Out:
#                                Prospect ID  Lead Number  \
# 2307  23f45ed6-f34c-4015-9b0a-581cf7fb79ee       637409
# 2511  8712596a-6013-4840-a1a5-1ded98a19adf       635626
# 2821  93ca59c3-d429-417f-ab3f-46f097a979bb       632692
# 2897  d0905fc2-e232-45fb-acac-ad1d483e1525       631854
# 3203  f693004e-815a-4b31-bd50-e9de0f097a6d       629389
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 2307                      API      Olark Chat           No          No
# 2511  Landing Page Submission  Direct Traffic           No          No
# 2821  Landing Page Submission  Direct Traffic           No          No
# 2897  Landing Page Submission  Organic Search           No          No
# 3203  Landing Page Submission  Direct Traffic           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 2307          1         12.0                          333
# 2511          0         14.0                          470
# ...

# %%
df['Through Recommendations'].value_counts()   #dropit
# Out:
# No     9233
# Yes       7
# Name: Through Recommendations, dtype: int64

# %%
df['Search'].value_counts()                      #dropit
# Out:
# No     9226
# Yes      14
# Name: Search, dtype: int64

# %%
df['Newspaper Article'].value_counts()                     #dropit
# Out:
# No     9238
# Yes       2
# Name: Newspaper Article, dtype: int64

# %%
df['X Education Forums'].value_counts()                     #dropit
# Out:
# No     9239
# Yes       1
# Name: X Education Forums, dtype: int64

# %%
df['Digital Advertisement'].value_counts()                   #dropit
# Out:
# No     9236
# Yes       4
# Name: Digital Advertisement, dtype: int64

# %%
df['Receive More Updates About Our Courses'].value_counts()     #dropit
# Out:
# No    9240
# Name: Receive More Updates About Our Courses, dtype: int64

# %%
df['Tags'].value_counts(dropna=False,normalize=True)            # impute
# Out:
# NaN                                                  0.362879
# Will revert after reading the email                  0.224242
# Ringing                                              0.130195
# Interested in other courses                          0.055519
# Already a student                                    0.050325
# Closed by Horizzon                                   0.038745
# switched off                                         0.025974
# Busy                                                 0.020130
# Lost to EINS                                         0.018939
# Not doing further education                          0.015693
# Interested  in full time MBA                         0.012662
# Graduation in progress                               0.012013
# invalid number                                       0.008983
# Diploma holder (Not Eligible)                        0.006818
# wrong number given                                   0.005087
# ...

# %%
df['Lead Quality'].value_counts(dropna=False)                   # binning, imputation
# Out:
# NaN                  4767
# Might be             1560
# Not Sure             1092
# High in Relevance     637
# Worst                 601
# Low in Relevance      583
# Name: Lead Quality, dtype: int64

# %%
df['Update me on Supply Chain Content'].value_counts()     #dropit
# Out:
# No    9240
# Name: Update me on Supply Chain Content, dtype: int64

# %%
df['Get updates on DM Content'].value_counts()     #dropit
# Out:
# No    9240
# Name: Get updates on DM Content, dtype: int64

# %%
df['Lead Profile'].value_counts(dropna=False)                     #impute
# Out:
# Select                         4146
# NaN                            2709
# Potential Lead                 1613
# Other Leads                     487
# Student of SomeSchool           241
# Lateral Student                  24
# Dual Specialization Student      20
# Name: Lead Profile, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Mumbai                         3222
# Select                         2249
# Thane & Outskirts               752
# Other Cities                    686
# Other Cities of Maharashtra     457
# Other Metro Cities              380
# Tier II Cities                   74
# Name: City, dtype: int64

# %% [raw]
# #  binning in tier1  => mumbai ,Other Metro Cities
#               tier2  => Tier II Cities, Thane & Outskirts
#               Tier3 => left categories

# %%
# 'Asymmetrique Activity Index' , 'Asymmetrique Activity Score'

# %%
sns.boxplot(x=df['Asymmetrique Activity Index'],y=df['Asymmetrique Activity Score'])
plt.show()

# %%
# 'Asymmetrique Profile Score' , 'Asymmetrique Profile Index'

# %%
sns.boxplot(x=df['Asymmetrique Profile Index'],y=df['Asymmetrique Profile Score'])
plt.show()

# %%
df['A free copy of Mastering The Interview'].value_counts(dropna=False)
# Out:
# No     6352
# Yes    2888
# Name: A free copy of Mastering The Interview, dtype: int64

# %%
df['Last Notable Activity'].value_counts(dropna=False)                   # binning
# Out:
# Modified                        3407
# Email Opened                    2827
# SMS Sent                        2172
# Page Visited on Website          318
# Olark Chat Conversation          183
# Email Link Clicked               173
# Email Bounced                     60
# Unsubscribed                      47
# Unreachable                       32
# Had a Phone Conversation          14
# Email Marked Spam                  2
# Form Submitted on Website          1
# Email Received                     1
# View in browser link Clicked       1
# Approached upfront                 1
# Resubscribed to emails             1
# Name: Last Notable Activity, dtype: int64
